# %% [markdown]
# # python is a interprator and open source(free ware) language.
# # Keywords:- These are reserved word in python where used to predefined the intepretor
# # ex:- if,else,for, while, break,cotline, return ,etc.
# # Identifier:- these are the name given to the variable,function,classes,etc.
# # Rules for Identifiers :-
#   1. we can use alphabets(A-Z,a-z), numbers(0-9) and underscore( _ ).
#   2. we can't start with numbers(digit)
#   3. keyword can't be used as name
# # Variable:- it contain use to store data
#   1. two or more variable having same value will also same
#   2.

# %%
print("Hello World")
# Out:
# Hello World
